# %%
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
import tensorflow as tf
import sys
import os
file = "/Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/analyze/analyze.ipynb"
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(file))))


from analyze import get_names, read_results, delete_results, get_cases, params_names, load_results

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pickle5 import pickle

import pdb

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline


from os import listdir

import pandas as pd
# from IPython.display import display

# %%
path='/Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/testcases/results/'
cases = get_cases(path, filter_case=None, print_cases=True)
p1, p2, p3 = params_names()
# Out:
# Cases:
# spy_1hr_3rd_dim528_ld3_sine_x001
# spy_1min_2nd_dim256_ld2_x0.02
# spy_1min_2nd_dim256_sinF
# spy_1min_2nd_dim128
# spy_15min_2nd_dim100_ld2
# spy_1min_2nd_dim256
# spy_1hr_3rd_dim528_ld3_sine
# spy_1min_2nd_dim128_ld2_x0-01_rec33
# spy_1min_2nd_dim256_ld2_x0.015
# spy_1hr_3rd_dim64_ld3_sine_x001
# spy_1min_2nd_dim256_ld2_x0-01
# spy_test_2nd_dim256_ld2_rec4_sindyx01
# spy_1min
# spy_1min_3rd_dim528
# spy_15min_3rd_dim528_ld3_sine
# spy_1min_3rd_dim528_ld3
# spy_1min_2nd_dim128_ld2_x0-011_rec28
# spy_15min_3rd_dim528_ld3
# spy_1min_2nd_dim528

# %%
name_list = get_names(cases, path)
for idx, name in enumerate(name_list): print(idx, name)
# Out:
# 0 results_202410031948_spy_1hr_3rd_dim64_ld3_sine_x001
# 1 results_202410031905_spy_1hr_3rd_dim64_ld3_sine_x001
# 2 results_202410031834_spy_1hr_3rd_dim528_ld3_sine_x001
# 3 results_202410031824_spy_1hr_3rd_dim528_ld3_sine_x001
# 4 results_202410031820_spy_1hr_3rd_dim528_ld3_sine
# 5 results_202410031656_spy_15min_3rd_dim528_ld3_sine
# 6 results_202410031653_spy_15min_3rd_dim528_ld3
# 7 results_202410031644_spy_1min_3rd_dim528_ld3
# 8 results_202410031635_spy_1min_3rd_dim528
# 9 results_202410031602_spy_1min_2nd_dim528
# 10 results_202410031556_spy_15min_2nd_dim100_ld2
# 11 results_202410021348_spy_test_2nd_dim256_ld2_rec4_sindyx01
# 12 results_202410011128_spy_1min_2nd_dim128_ld2_x0-01_rec33
# 13 results_202410011036_spy_1min_2nd_dim128_ld2_x0-011_rec28
# 14 results_202410010853_spy_1min_2nd_dim256_ld2_x0-01
# 15 results_202410010816_spy_1min_2nd_dim256_ld2_x0.015
# 16 results_202409302304_spy_1min_2nd_dim256_ld2_x0.02
# 17 results_202409301754_spy_1min_2nd_dim256_sinF
# 18 results_202409301719_spy_1min_2nd_dim256
# 19 results_202409301638_spy_1min_2nd_dim128
# 20 results_202409301523_spy_1min

# %%
# raw_data = call_polygon('SPY','2017-01-01','2024-07-01','minute',1)
# raw_data = raw_data[['c']]
# raw_data = raw_data.rename(columns={'c':'x'})
# data_dict = {
#     'x':[raw_data['x'].values],
#     'dt': 60
#     }

# data_builder = DatasetConstructor(input_dim=params['input_dim'],
#                 interpolate=params['interpolate'],
#                 interp_dt=params['interp_dt'],
#                 savgol_interp_coefs=params['interp_coefs'],
#                 interp_kind=params['interp_kind'])
# data_builder.build_solution(data_dict)
# train_data = data_builder.get_data()
# print(train_data)
# trainer = TrainModel(train_data, params)
# trainer.fit()

# %%
end_time = 30
end_time_plot = 100
display_params = p1 #primary_params + secondary_params + tertiary_params
t0_frac = 0.2
query_remove = True

non_existing_files, non_existing_params, remove_files = read_results([name_list[0]], 
                                                        path, 
                                                        end_time=end_time, 
                                                        display_params=display_params, 
                                                        t0_frac=t0_frac, 
                                                        end_time_plot=end_time_plot,
                                                        query_remove=query_remove,
                                                        known_attractor=False)
# Out:
# name:  results_202410031948_spy_1hr_3rd_dim64_ld3_sine_x001
# /Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/testcases/results/results_202410031948_spy_1hr_3rd_dim64_ld3_sine_x001
# loaded
# got results...
# TEST DATA
# [array([[417.26  , 416.1   , 416.42  , ..., 417.35  , 420.32  , 419.57  ],
#        [416.1   , 416.42  , 416.61  , ..., 420.32  , 419.57  , 418.92  ],
#        [416.42  , 416.61  , 416.31  , ..., 419.57  , 418.92  , 418.27  ],
#        ...,
#        [547.41  , 548.01  , 547.7657, ..., 545.05  , 544.92  , 544.8   ],
#        [548.01  , 547.7657, 548.27  , ..., 544.92  , 544.8   , 544.755 ],
#        [547.7657, 548.27  , 547.05  , ..., 544.8   , 544.755 , 544.33  ]]), array([[ 0.00225   , -0.007     ,  0.00425   , ...,  0.01966667,
#          0.0185    , -0.01166667],
#        [-0.007     ,  0.00425   , -0.00091667, ...,  0.0185    ,
#         -0.01166667, -0.01083333],
#        [ 0.00425   , -0.00091667, -0.00175   , ..., -0.01166667,
#         -0.01083333, -0.00383333],
#        ...,
#        [ 0.01383333,  0.00296417,  0.00216667, ..., -0.0009125 ,
#         -0.00208333, -0.001375  ],
#        [ 0.00296417,  0.00216667, -0.00596417, ..., -0.00208333,
#         -0.001375  , -0.00391667],
#        [ 0.00216667, -0.00596417, -0.00891667, ..., -0.001375  ,
#         -0.00391667,  0.005125  ]])]
# (11150, 128)
#
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# ------- COEFFICIENTS -------
#         x       y
# 1   9.769 -17.809
# x  13.977  -5.117
# y   3.109  -0.809
# xx 19.076   2.095
# xy  6.443  -4.790
# yy -3.360   2.011
# -------- Mask ------
#        x     y
# 1  1.000 1.000
# x  1.000 1.000
# y  1.000 1.000
# xx 1.000 1.000
# xy 1.000 1.000
# yy 1.000 1.000
# -------- Parameters ------
# case  :  1hr_3rd_dim64_ld3_sine_x001
# coefficient_initialization  :  random_normal
# exact_features  :  0
# fix_coefs  :  False
# input_dim  :  128
# latent_dim  :  2
# loss_weight_integral  :  0.05
# loss_weight_rec  :  0.3
# loss_weight_sindy_regularization  :  0.001
# loss_weight_sindy_x  :  0.0
# loss_weight_sindy_z  :  0.0
# loss_weight_x0  :  0.01
# model  :  spy
# n_ics  :  5
# widths_ratios  :  [0.5, 0.25]
# svd_dim  :  None
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2476004183732D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2476004183732D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2476004183732D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2476004183732D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2010256644947D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2010256644947D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2010256644947D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.2010256644947D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.1632118255226D-10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.3600000002709D+06   r2 =  0.1632118255226D-10
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# /Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/aesindy/sindy_utils.py:220: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   x = odeint(f, x0, t)
# Do you want to remove this file? Y/N
