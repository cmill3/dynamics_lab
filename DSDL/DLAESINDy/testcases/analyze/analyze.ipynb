# %%
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
import tensorflow as tf
import sys
import os
file = "/Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/analyze/analyze.ipynb"
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(file))))


from analyze import get_names, read_results, delete_results, get_cases, params_names, load_results

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pickle5 import pickle

import pdb

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline


from os import listdir

import pandas as pd
# from IPython.display import display

# %%
path='/Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/testcases/results/'
cases = get_cases(path, filter_case=None, print_cases=True)
p1, p2, p3 = params_names()
print(path)
# Out:
# spy_1min
# pendulum_basic
# /Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/testcases/results/

# %%
name_list = get_names(cases, path)
for idx, name in enumerate(name_list): print(idx, name)
# Out:
# 0 results_202409301523_spy_1min
# 1 results_202409241412_pendulum_basic
# 2 results_202409231627_pendulum_basic

# %%
# raw_data = call_polygon('SPY','2017-01-01','2024-07-01','minute',1)
# raw_data = raw_data[['c']]
# raw_data = raw_data.rename(columns={'c':'x'})
# data_dict = {
#     'x':[raw_data['x'].values],
#     'dt': 60
#     }

# data_builder = DatasetConstructor(input_dim=params['input_dim'],
#                 interpolate=params['interpolate'],
#                 interp_dt=params['interp_dt'],
#                 savgol_interp_coefs=params['interp_coefs'],
#                 interp_kind=params['interp_kind'])
# data_builder.build_solution(data_dict)
# train_data = data_builder.get_data()
# print(train_data)
# trainer = TrainModel(train_data, params)
# trainer.fit()

# %%
end_time = 30
end_time_plot = 100
display_params = p1 #primary_params + secondary_params + tertiary_params
t0_frac = 0.2
query_remove = True

non_existing_files, non_existing_params, remove_files = read_results([name_list[0]], 
                                                        path, 
                                                        end_time=end_time, 
                                                        display_params=display_params, 
                                                        t0_frac=t0_frac, 
                                                        end_time_plot=end_time_plot,
                                                        query_remove=query_remove,
                                                        known_attractor=False)
# Out:
# name:  results_202409301523_spy_1min
# /Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/testcases/results/results_202409301523_spy_1min
# loaded
# got results...
# TEST DATA
# [array([[226.706, 226.73 , 226.7  , ..., 227.118, 227.12 , 227.145],
#        [226.73 , 226.7  , 226.74 , ..., 227.12 , 227.145, 227.17 ],
#        [226.7  , 226.74 , 226.71 , ..., 227.145, 227.17 , 227.17 ],
#        ...,
#        [233.15 , 233.13 , 233.1  , ..., 233.245, 233.31 , 233.23 ],
#        [233.13 , 233.1  , 233.08 , ..., 233.31 , 233.23 , 233.26 ],
#        [233.1  , 233.08 , 233.15 , ..., 233.23 , 233.26 , 233.18 ]]), array([[ 4.71666667e-04, -5.00000000e-05,  8.33333333e-05, ...,
#         -2.50000000e-04,  2.25000000e-04,  4.16666667e-04],
#        [-5.00000000e-05,  8.33333333e-05,  8.33333333e-05, ...,
#          2.25000000e-04,  4.16666667e-04,  2.08333333e-04],
#        [ 8.33333333e-05,  8.33333333e-05, -4.58333333e-05, ...,
#          4.16666667e-04,  2.08333333e-04, -2.50000000e-04],
#        ...,
#        [-2.50000000e-04, -4.16666667e-04, -4.16666667e-04, ...,
#          5.83333333e-04, -1.25000000e-04, -4.16666667e-04],
#        [-4.16666667e-04, -4.16666667e-04,  4.16666667e-04, ...,
#         -1.25000000e-04, -4.16666667e-04, -4.16666667e-04],
#        [-4.16666667e-04,  4.16666667e-04,  5.83333333e-04, ...,
#         -4.16666667e-04, -4.16666667e-04, -6.66666667e-04]])]
# (23725, 80)
#
# 742/742 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# ------- COEFFICIENTS -------
#             x      y
# 1      -5.706 -2.655
# x       7.352 -0.098
# y       2.828 -2.680
# sin(x) 13.406  9.754
# sin(y) -5.666 -1.171
# -------- Mask ------
#            x     y
# 1      1.000 1.000
# x      1.000 1.000
# y      1.000 1.000
# sin(x) 1.000 1.000
# sin(y) 1.000 1.000
# -------- Parameters ------
# case  :  1min
# coefficient_initialization  :  random_normal
# exact_features  :  0
# fix_coefs  :  False
# input_dim  :  80
# latent_dim  :  2
# loss_weight_integral  :  0.1
# loss_weight_rec  :  0.3
# loss_weight_sindy_regularization  :  1e-05
# loss_weight_sindy_x  :  0.001
# loss_weight_sindy_z  :  0.001
# loss_weight_x0  :  0.01
# model  :  spy
# n_ics  :  30
# widths_ratios  :  [0.5, 0.25]
# svd_dim  :  None
# /Users/charlesmiller/Documents/Code/dynamics_lab/DSDL/DLAESINDy/aesindy/sindy_utils.py:220: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   x = odeint(f, x0, t)
# Do you want to remove this file? Y/N
